# %%
# needed as this function doesn't like it when the lm_head has its size changed
from unsloth import tokenizer_utils
def do_nothing(*args, **kwargs):
    pass
tokenizer_utils.fix_untrained_tokens = do_nothing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # needed as this function doesn't like it when the lm_head has its size changed
# ----> 2 from unsloth import tokenizer_utils
#       3 def do_nothing(*args, **kwargs):
#       4     pass
#       5 tokenizer_utils.fix_untrained_tokens = do_nothing
#
# ModuleNotFoundError: No module named 'unsloth'
